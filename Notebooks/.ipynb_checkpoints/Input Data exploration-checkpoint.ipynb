# %%
import pandas as pd
import numpy as np
import os
os.chdir(os.path.dirname(os.getcwd()))
import matplotlib.pyplot as plt
from matplotlib import style
from statsmodels.tsa.seasonal import seasonal_decompose
style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # Weather data

# %%
weather = pd.read_csv('data/environment/ninja_weather_55.6838_12.5354_uncorrected.csv',header=3)

# %%
weather.index = weather.time

# %%
weather
# Out:
#                               time        local_time  temperature  \
# time
# 2014-01-01 00:00  2014-01-01 00:00  2014-01-01 01:00        2.118
# 2014-01-01 01:00  2014-01-01 01:00  2014-01-01 02:00        2.147
# 2014-01-01 02:00  2014-01-01 02:00  2014-01-01 03:00        2.324
# 2014-01-01 03:00  2014-01-01 03:00  2014-01-01 04:00        2.344
# 2014-01-01 04:00  2014-01-01 04:00  2014-01-01 05:00        2.384
# ...                            ...               ...          ...
# 2014-12-31 19:00  2014-12-31 19:00  2014-12-31 20:00        3.075
# 2014-12-31 20:00  2014-12-31 20:00  2014-12-31 21:00        3.164
# 2014-12-31 21:00  2014-12-31 21:00  2014-12-31 22:00        3.210
# 2014-12-31 22:00  2014-12-31 22:00  2014-12-31 23:00        3.247
# 2014-12-31 23:00  2014-12-31 23:00  2015-01-01 00:00        3.243
#
#                   radiation_surface
# time
# 2014-01-01 00:00                0.0
# 2014-01-01 01:00                0.0
# 2014-01-01 02:00                0.0
# 2014-01-01 03:00                0.0
# 2014-01-01 04:00                0.0
# ...                             ...
# 2014-12-31 19:00                0.0
# 2014-12-31 20:00                0.0
# 2014-12-31 21:00                0.0
# 2014-12-31 22:00                0.0
# 2014-12-31 23:00                0.0
#
# [8760 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Radiation Surface')
plt.xlabel('Date')
weather.loc[:,'radiation_surface'].plot(ax=ax)

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Temperature')
weather.loc[:,'temperature'].plot(ax=ax)

# %%
weather.describe()
# Out:
#        temperature  radiation_surface
# count  8760.000000        8760.000000
# mean      9.996626         133.634475
# std       6.662291         211.872905
# min      -6.557000           0.000000
# 25%       4.353250           0.000000
# 50%      10.026500           4.391500
# 75%      15.174500         190.447000
# max      26.763000         875.069000

# %%
start = pd.to_datetime('2014-11-07', infer_datetime_format=True)
end = pd.to_datetime('2014-11-14', infer_datetime_format=True)
time = pd.to_datetime(weather['time'], infer_datetime_format=True)
weather['time']=time

# %%
f, ax = plt.subplots(2,1,figsize=(15,7), sharex=True)

ax[0].set_ylabel('Radiation Surface (W/m^2)')
weather.loc[(weather['time'] <= end) & (weather['time'] >= start),'radiation_surface'].plot(ax=ax[0])

ax[1].set_ylabel('Temperature (°C)')
weather.loc[(weather['time'] <= end) & (weather['time'] >= start),'temperature'].plot(ax=ax[1])
plt.savefig('data/output/nov_dec_weather.png',bbox_inches='tight')

# %%
start = pd.to_datetime('2014-11-01', infer_datetime_format=True)
end = pd.to_datetime('2014-12-31', infer_datetime_format=True)

weather.loc[(weather['time'] < end) & (weather['time'] >= start),'temperature'].describe()
# Out:
# count    1440.000000
# mean        5.329065
# std         3.597932
# min        -6.557000
# 25%         3.207500
# 50%         5.209500
# 75%         8.015750
# max        14.425000
# Name: temperature, dtype: float64

# %%
start = pd.to_datetime('2014-01-01', infer_datetime_format=True)
end = pd.to_datetime('2014-01-31', infer_datetime_format=True)

weather.loc[(weather['time'] < end) & (weather['time'] >= start),'temperature'].describe()
# Out:
# count    720.000000
# mean       1.202497
# std        3.476593
# min       -6.366000
# 25%       -1.613250
# 50%        1.135000
# 75%        4.364000
# max        7.741000
# Name: temperature, dtype: float64

# %%
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Temperature (°C)')
weather.loc[(weather['time'] < end) & (weather['time'] >= start),'temperature'].plot(ax=ax)

# %%
import random
random_day = random.randint(0,363)*24
weather.iloc[random_day:random_day+24,2][3]#.loc['temperature']
# Out:
# 6.492000000000001

# %% [markdown]
# # Electricity prices

# %%
prices = pd.read_excel('data/environment/2014_spot_prices.xlsx')

# %%
prices['hour']=prices['Hours'].map(lambda x: x.split('-')[0].strip())

# %%
prices
# Out:
#                      Date    Hours    SYS    SE1    SE2    SE3    SE4     FI  \
# 0     2014-01-01 00:00:00  00 - 01  28,53  28,67  28,67  28,67  28,67  28,67
# 1     2014-01-01 00:00:00  01 - 02  28,01  28,08  28,08  28,08  28,08  28,08
# 2     2014-01-01 00:00:00  02 - 03  27,16  27,38  27,38  27,38  27,38  27,38
# 3     2014-01-01 00:00:00  03 - 04  26,05  26,21  26,21  26,21  26,21  26,21
# 4     2014-01-01 00:00:00  04 - 05  25,16  25,98  25,98  25,98  25,98  25,98
# ...                   ...      ...    ...    ...    ...    ...    ...    ...
# 8756           31-12-2014  19 - 20  29,54  29,49  29,49  29,49  29,49  30,93
# 8757           31-12-2014  20 - 21  29,10  29,09  29,09  29,09  29,09  29,09
# 8758           31-12-2014  21 - 22  28,83  28,82  28,82  28,82  28,82  28,82
# 8759           31-12-2014  22 - 23  28,61  28,61  28,61  28,61  28,61  28,61
# 8760           31-12-2014  23 - 00  28,09  28,02  28,02  28,02  28,02  28,02
#
#         DK1    DK2  ... Kr.sand Bergen  Molde Tr.heim Tromsø     EE     LV  \
# 0     15,15  15,15  ...   29,07  29,07  28,67   28,67  28,67  28,67  32,06
# 1     12,96  12,96  ...   28,81  28,81  28,08   28,08  28,08  28,08  32,02
# 2     12,09  12,09  ...   28,42  28,42  27,38   27,38  27,38  27,38  27,38
# 3     11,70  11,70  ...   27,63  27,63  26,21   26,21  26,21  26,21  26,21
# 4     11,66  11,66  ...   25,98  25,98  25,98   25,98  25,98  25,98  25,98
# ...     ...    ...  ...     ...    ...    ...     ...    ...    ...    ...
# 8756  29,49  29,49  ...   29,49  29,49  29,49   29,49  29,49  30,93  46,05
# 8757  29,09  29,09  ...   29,09  29,09  29,09   29,09  29,09  29,09  45,78
# 8758  28,82  28,82  ...   28,82  28,82  28,82   28,82  28,82  28,82  45,58
# 8759  28,61  28,61  ...   28,61  28,61  28,61   28,61  28,61  28,61  29,06
# 8760  28,02  28,02  ...   28,02  28,02  28,54   28,54  28,54  28,02  28,04
#
#          LT string_date hour
# 0     32,06  01/01/2014   00
# 1     32,02  01/01/2014   01
# 2     27,38  01/01/2014   02
# 3     26,21  01/01/2014   03
# 4     25,98  01/01/2014   04
# ...     ...         ...  ...
# 8756  46,05  31-12-2014   19
# 8757  45,78  31-12-2014   20
# 8758  45,58  31-12-2014   21
# 8759  29,06  31-12-2014   22
# 8760  28,04  31-12-2014   23
#
# [8761 rows x 21 columns]

# %%
def extract_date(x,column):
    if column == 1:
        try: 
            return x.split('/')[1]
        except: 
            return x.split('-')[1]
    else:
        try: 
            x.split('/')[1]
            return x.split('/')[0]
        except: 
            return x.split('-')[0]
prices['year']='2014'
prices['month']=prices['string_date'].map(lambda x: extract_date(x,1))
prices['day']=prices['string_date'].map(lambda x: extract_date(x,0))

# %%
prices
# Out:
#                      Date    Hours    SYS    SE1    SE2    SE3    SE4     FI  \
# 0     2014-01-01 00:00:00  00 - 01  28,53  28,67  28,67  28,67  28,67  28,67
# 1     2014-01-01 00:00:00  01 - 02  28,01  28,08  28,08  28,08  28,08  28,08
# 2     2014-01-01 00:00:00  02 - 03  27,16  27,38  27,38  27,38  27,38  27,38
# 3     2014-01-01 00:00:00  03 - 04  26,05  26,21  26,21  26,21  26,21  26,21
# 4     2014-01-01 00:00:00  04 - 05  25,16  25,98  25,98  25,98  25,98  25,98
# ...                   ...      ...    ...    ...    ...    ...    ...    ...
# 8756           31-12-2014  19 - 20  29,54  29,49  29,49  29,49  29,49  30,93
# 8757           31-12-2014  20 - 21  29,10  29,09  29,09  29,09  29,09  29,09
# 8758           31-12-2014  21 - 22  28,83  28,82  28,82  28,82  28,82  28,82
# 8759           31-12-2014  22 - 23  28,61  28,61  28,61  28,61  28,61  28,61
# 8760           31-12-2014  23 - 00  28,09  28,02  28,02  28,02  28,02  28,02
#
#         DK1    DK2  ... Tr.heim Tromsø     EE     LV     LT string_date hour  \
# 0     15,15  15,15  ...   28,67  28,67  28,67  32,06  32,06  01/01/2014   00
# 1     12,96  12,96  ...   28,08  28,08  28,08  32,02  32,02  01/01/2014   01
# 2     12,09  12,09  ...   27,38  27,38  27,38  27,38  27,38  01/01/2014   02
# 3     11,70  11,70  ...   26,21  26,21  26,21  26,21  26,21  01/01/2014   03
# 4     11,66  11,66  ...   25,98  25,98  25,98  25,98  25,98  01/01/2014   04
# ...     ...    ...  ...     ...    ...    ...    ...    ...         ...  ...
# 8756  29,49  29,49  ...   29,49  29,49  30,93  46,05  46,05  31-12-2014   19
# 8757  29,09  29,09  ...   29,09  29,09  29,09  45,78  45,78  31-12-2014   20
# 8758  28,82  28,82  ...   28,82  28,82  28,82  45,58  45,58  31-12-2014   21
# 8759  28,61  28,61  ...   28,61  28,61  28,61  29,06  29,06  31-12-2014   22
# 8760  28,02  28,02  ...   28,54  28,54  28,02  28,04  28,04  31-12-2014   23
#
#       year month day
# 0     2014    01  01
# 1     2014    01  01
# 2     2014    01  01
# 3     2014    01  01
# 4     2014    01  01
# ...    ...   ...  ..
# 8756  2014    12  31
# 8757  2014    12  31
# 8758  2014    12  31
# 8759  2014    12  31
# 8760  2014    12  31
#
# [8761 rows x 24 columns]

# %%
prices['date']=pd.to_datetime(prices[['year','month','day','hour']])

# %%
prices['DK2']=prices['DK2'].map(lambda x: float(x.replace(',','.')) if type(x)==str else x)

# %%
prices.index = prices.date
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Price')
prices.loc[:,'DK2'].plot(ax=ax)

# %%
jan_first_week = prices.loc[prices['date'] < pd.to_datetime('2014-01-08',infer_datetime_format=True)]

# %%
jan_first_week.index = jan_first_week.date
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Price (€/Mwh)')
jan_first_week.loc[:,'DK2'].plot(ax=ax)

# %%
import random
random_day=random.randint(304,365-7*24//24-1)*24
random_nov_dec = prices.iloc[random_day:random_day+7*24+1,:].loc[:,['DK2','date']]

# %%
random_nov_dec.index = random_nov_dec.date
result = seasonal_decompose(random_nov_dec['DK2'], model='additive')

f, ax = plt.subplots(4,1,figsize=(15,7), sharex=True)
ax[0].plot(result.observed.index,result.observed)
ax[0].set_ylabel('Observed')
ax[1].plot(result.observed.index,result.seasonal)
ax[1].set_ylabel('Seasonal')
ax[2].plot(result.observed.index,result.trend)
ax[2].set_ylabel('Trend')
ax[3].scatter(result.observed.index,result.resid)
#ax[3].xlim(result.observed.index[0], result.observed.index[-1])
ax[3].set_ylabel('Residual')
plt.savefig('data/output/nov_dec_price.png',bbox_inches='tight')

# %%
prices.iloc[304*24:,:].describe()
# Out:
#                DK2
# count  1465.000000
# mean     32.811119
# std      10.474592
# min     -30.850000
# 25%      29.670000
# 50%      31.240000
# 75%      33.290000
# max      84.120000

# %%
prices.iloc[0:30*24,:].describe()
# Out:
#               DK2
# count  720.000000
# mean    30.918750
# std     10.777951
# min     -0.050000
# 25%     29.197500
# 50%     31.095000
# 75%     33.857500
# max     70.680000

# %%
prices
# Out:
#                      Date    Hours    SYS    SE1    SE2    SE3    SE4     FI  \
# 0     2014-01-01 00:00:00  00 - 01  28,53  28,67  28,67  28,67  28,67  28,67
# 1     2014-01-01 00:00:00  01 - 02  28,01  28,08  28,08  28,08  28,08  28,08
# 2     2014-01-01 00:00:00  02 - 03  27,16  27,38  27,38  27,38  27,38  27,38
# 3     2014-01-01 00:00:00  03 - 04  26,05  26,21  26,21  26,21  26,21  26,21
# 4     2014-01-01 00:00:00  04 - 05  25,16  25,98  25,98  25,98  25,98  25,98
# ...                   ...      ...    ...    ...    ...    ...    ...    ...
# 8756           31-12-2014  19 - 20  29,54  29,49  29,49  29,49  29,49  30,93
# 8757           31-12-2014  20 - 21  29,10  29,09  29,09  29,09  29,09  29,09
# 8758           31-12-2014  21 - 22  28,83  28,82  28,82  28,82  28,82  28,82
# 8759           31-12-2014  22 - 23  28,61  28,61  28,61  28,61  28,61  28,61
# 8760           31-12-2014  23 - 00  28,09  28,02  28,02  28,02  28,02  28,02
#
#         DK1    DK2  ... Tromsø     EE     LV     LT string_date hour  year  \
# 0     15,15  15.15  ...  28,67  28,67  32,06  32,06  01/01/2014   00  2014
# 1     12,96  12.96  ...  28,08  28,08  32,02  32,02  01/01/2014   01  2014
# 2     12,09  12.09  ...  27,38  27,38  27,38  27,38  01/01/2014   02  2014
# 3     11,70  11.70  ...  26,21  26,21  26,21  26,21  01/01/2014   03  2014
# 4     11,66  11.66  ...  25,98  25,98  25,98  25,98  01/01/2014   04  2014
# ...     ...    ...  ...    ...    ...    ...    ...         ...  ...   ...
# 8756  29,49  29.49  ...  29,49  30,93  46,05  46,05  31-12-2014   19  2014
# 8757  29,09  29.09  ...  29,09  29,09  45,78  45,78  31-12-2014   20  2014
# 8758  28,82  28.82  ...  28,82  28,82  45,58  45,58  31-12-2014   21  2014
# 8759  28,61  28.61  ...  28,61  28,61  29,06  29,06  31-12-2014   22  2014
# 8760  28,02  28.02  ...  28,54  28,02  28,04  28,04  31-12-2014   23  2014
#
#      month day                date
# 0       01  01 2014-01-01 00:00:00
# 1       01  01 2014-01-01 01:00:00
# 2       01  01 2014-01-01 02:00:00
# 3       01  01 2014-01-01 03:00:00
# 4       01  01 2014-01-01 04:00:00
# ...    ...  ..                 ...
# 8756    12  31 2014-12-31 19:00:00
# 8757    12  31 2014-12-31 20:00:00
# 8758    12  31 2014-12-31 21:00:00
# 8759    12  31 2014-12-31 22:00:00
# 8760    12  31 2014-12-31 23:00:00
#
# [8761 rows x 25 columns]

# %%
from statsmodels.distributions.empirical_distribution import ECDF
nov_dec = prices.iloc[304*24:]
nov_dec_cumulative = ECDF(nov_dec['DK2'])

# %%
price_range = [p for p in range(-10,80)]


data = []

for p in price_range:
    data.append(nov_dec_cumulative(p))
    

f, ax = plt.subplots(figsize=(15,7))

plt.xlabel('Price (€/MWh)')
plt.plot(price_range, data)
#plt.savefig('data/output/nov_dec_price.png',bbox_inches='tight')

# %%
from statsmodels.distributions.empirical_distribution import ECDF
jan = prices.iloc[:24*31]
jan_cumulative = ECDF(jan['DK2'])

# %%
price_range = [p for p in range(-10,80)]


data = []

for p in price_range:
    data.append(jan_cumulative(p))
    

f, ax = plt.subplots(figsize=(15,7))

plt.xlabel('Price (€/MWh)')
plt.plot(price_range, data)
#plt.savefig('data/output/nov_dec_price.png',bbox_inches='tight')

# %%
f, ax = plt.subplots(figsize=(15,7))
result = seasonal_decompose(jan['DK2'], model='additive')

# %%
f, ax = plt.subplots(4,1,figsize=(15,7),sharex=True)
ax[0].plot(result.observed.index,result.observed)
ax[0].set_ylabel('Observed')
ax[1].plot(result.observed.index,result.seasonal)
ax[1].set_ylabel('Seasonal')
ax[2].plot(result.observed.index,result.trend)
ax[2].set_ylabel('Trend')
ax[3].scatter(result.observed.index,result.resid)
#ax[3].xlim(result.observed.index[0], result.observed.index[-1])
ax[3].set_ylabel('Residual')
plt.savefig('data/output/jan_price.png',bbox_inches='tight')

# %%
jan.index = prices.iloc[:24*31].date

# %%
prices['DK2'].to_csv('2014_DK2_spot_prices.csv')
