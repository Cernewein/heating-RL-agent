# %%
import pandas as pd
import numpy as np
import os
os.chdir(os.path.dirname(os.getcwd()))
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # Weather data

# %%
weather = pd.read_csv('data/environment/ninja_weather_55.6838_12.5354_uncorrected.csv',header=3)

# %%
weather.index = weather.time

# %%
weather
# Out:
#                               time        local_time  temperature  \
# time
# 2014-01-01 00:00  2014-01-01 00:00  2014-01-01 01:00        2.118
# 2014-01-01 01:00  2014-01-01 01:00  2014-01-01 02:00        2.147
# 2014-01-01 02:00  2014-01-01 02:00  2014-01-01 03:00        2.324
# 2014-01-01 03:00  2014-01-01 03:00  2014-01-01 04:00        2.344
# 2014-01-01 04:00  2014-01-01 04:00  2014-01-01 05:00        2.384
# ...                            ...               ...          ...
# 2014-12-31 19:00  2014-12-31 19:00  2014-12-31 20:00        3.075
# 2014-12-31 20:00  2014-12-31 20:00  2014-12-31 21:00        3.164
# 2014-12-31 21:00  2014-12-31 21:00  2014-12-31 22:00        3.210
# 2014-12-31 22:00  2014-12-31 22:00  2014-12-31 23:00        3.247
# 2014-12-31 23:00  2014-12-31 23:00  2015-01-01 00:00        3.243
#
#                   radiation_surface
# time
# 2014-01-01 00:00                0.0
# 2014-01-01 01:00                0.0
# 2014-01-01 02:00                0.0
# 2014-01-01 03:00                0.0
# 2014-01-01 04:00                0.0
# ...                             ...
# 2014-12-31 19:00                0.0
# 2014-12-31 20:00                0.0
# 2014-12-31 21:00                0.0
# 2014-12-31 22:00                0.0
# 2014-12-31 23:00                0.0
#
# [8760 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Radiation Surface')
weather.loc[:,'radiation_surface'].plot(ax=ax)

# %%
weather.describe()
# Out:
#        temperature  radiation_surface
# count  8760.000000        8760.000000
# mean      9.996626         133.634475
# std       6.662291         211.872905
# min      -6.557000           0.000000
# 25%       4.353250           0.000000
# 50%      10.026500           4.391500
# 75%      15.174500         190.447000
# max      26.763000         875.069000

# %%
start = pd.to_datetime('2014-05-01', infer_datetime_format=True)
end = pd.to_datetime('2014-05-02', infer_datetime_format=True)
time = pd.to_datetime(weather['time'], infer_datetime_format=True)
weather['time']=time

# %%
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Radiation Surface (W/m^2)')
weather.loc[(weather['time'] < end) & (weather['time'] >= start),'radiation_surface'].plot(ax=ax)

# %%
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Temperature (°C)')
weather.loc[(weather['time'] < end) & (weather['time'] >= start),'temperature'].plot(ax=ax)

# %%
import random
random_day = random.randint(0,363)*24
weather.iloc[random_day:random_day+24,2][3]#.loc['temperature']
# Out:
# 6.492000000000001

# %% [markdown]
# # Electricity prices

# %%
prices = pd.read_excel('data/environment/2018_spot_prices.xlsx')

# %%
prices['hour']=prices['Hours'].map(lambda x: x.split('-')[0].strip())

# %%
def extract_date(x,column):
    if column == 1:
        try: 
            return x.month
        except: 
            return x.split('-')[1]
    else:
        try: 
            return x.day
        except: 
            return x.split('-')[0]
prices['year']='2018'
prices['month']=prices['Date'].map(lambda x: extract_date(x,1))
prices['day']=prices['Date'].map(lambda x: extract_date(x,0))

# %%
prices
# Out:
#                      Date    Hours    SYS    SE1    SE2    SE3    SE4     FI  \
# 0     2018-01-01 00:00:00  00 - 01  26,31  26,33  26,33  26,33  26,33  26,33
# 1     2018-01-01 00:00:00  01 - 02  26,43  26,43  26,43  26,43  26,43  26,43
# 2     2018-01-01 00:00:00  02 - 03  26,09  26,10  26,10  26,10  26,10  26,10
# 3     2018-01-01 00:00:00  03 - 04  24,63  24,70  24,70  24,70  24,70  24,70
# 4     2018-01-01 00:00:00  04 - 05  24,67  24,74  24,74  24,74  24,74  24,74
# ...                   ...      ...    ...    ...    ...    ...    ...    ...
# 8756           31-12-2018  19 - 20  48,83  47,51  47,51  47,51  47,51  47,51
# 8757           31-12-2018  20 - 21  47,23  45,82  45,82  45,82  45,82  45,82
# 8758           31-12-2018  21 - 22  46,02  43,03  43,03  43,03  43,03  43,03
# 8759           31-12-2018  22 - 23  45,55  38,54  38,54  38,54  38,54  38,54
# 8760           31-12-2018  23 - 00  42,69  25,70  25,70  25,70  25,70  25,70
#
#         DK1    DK2  ...  Molde Tr.heim Tromsø     EE     LV     LT hour  year  \
# 0     21,80  26,33  ...  26,33   26,33  26,33  26,33  26,33  26,33   00  2018
# 1     26,43  26,43  ...  26,43   26,43  26,43  26,43  26,43  26,43   01  2018
# 2     26,10  26,10  ...  26,10   26,10  26,10  26,10  26,10  26,10   02  2018
# 3     24,70  24,70  ...  24,70   24,70  24,70  24,70  24,70  24,70   03  2018
# 4     24,74  24,74  ...  24,74   24,74  24,74  24,74  24,74  24,74   04  2018
# ...     ...    ...  ...    ...     ...    ...    ...    ...    ...  ...   ...
# 8756  47,51  47,51  ...  47,51   47,51  47,51  47,51  47,51  47,51   19  2018
# 8757  45,82  45,82  ...  45,82   45,82  45,82  45,82  45,82  45,82   20  2018
# 8758  43,03  43,03  ...  45,41   45,41  45,41  43,03  43,03  43,03   21  2018
# 8759  38,54  38,54  ...  43,97   43,97  43,97  38,54  38,54  38,54   22  2018
# 8760  25,70  25,70  ...  43,01   43,01  43,01  25,70  25,70  25,70   23  2018
#
#      month day
# 0        1   1
# 1        1   1
# 2        1   1
# 3        1   1
# 4        1   1
# ...    ...  ..
# 8756    12  31
# 8757    12  31
# 8758    12  31
# 8759    12  31
# 8760    12  31
#
# [8761 rows x 23 columns]

# %%
prices['date']=pd.to_datetime(prices[['year','month','day','hour']])

# %%
prices['DK2']=prices['DK2'].map(lambda x: float(x.replace(',','.')) if type(x)==str else x)

# %%
prices.index = prices.date
f, ax = plt.subplots(figsize=(15,7))

plt.ylabel('Price')
prices.loc[:,'DK2'].plot(ax=ax)
