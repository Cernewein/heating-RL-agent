# %%
import pickle as pkl
import matplotlib.pyplot as plt
from matplotlib import style
import os 
os.chdir(os.path.dirname(os.getcwd()))
import pandas as pd
style.use('ggplot')
# %matplotlib inline

# %%
temperatures = pkl.load(open('temperatures.pkl', "rb"))

temperatures_df = pd.DataFrame()
temperatures_df['trained'] = temperatures[-1]
temperatures_df['untrained'] = temperatures[0]
temperatures_df['hour'] = pd.to_timedelta(temperatures_df.index, unit='s')

# %%
temperatures_df.index = temperatures_df['hour']

# %%
plt.figure(figsize=(10,10))
temperatures_df.loc[temperatures_df['hour'] < pd.to_timedelta(43200, unit='s'),'trained'].plot()

# %%
rewards = pkl.load(open('rewards.pkl', "rb"))

rewards_df = pd.DataFrame()
rewards_df['reward'] = rewards

# %%
rewards_df.plot()

# %%
rewards[-1]
# Out:
# -230290

# %%
temperatures = pkl.load(open('temperatures_basic.pkl', "rb"))

temperatures_df = pd.DataFrame()
temperatures_df['trained'] = temperatures
temperatures_df['hour'] = pd.to_timedelta(temperatures_df.index, unit='s')

# %%
temperatures_df.index = temperatures_df['hour']

# %%
plt.figure(figsize=(10,5))
temperatures_df.loc[temperatures_df['hour'] < pd.to_timedelta(24300, unit='s'),'trained'].plot()

# %%
temperatures_df['trained'].plot()

# %%
rewards = pkl.load(open('rewards_basic.pkl', "rb"))

rewards_df = pd.DataFrame()
rewards_df['reward'] = rewards

# %%
sum(rewards)
# Out:
# -431310
